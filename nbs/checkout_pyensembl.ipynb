# %%
import pyensembl
from pyensembl import Genome

# %%
pwd
# Out:
# '/data/nasif12/home_if12/kotova/project/gfeat/nbs'

# %%
ref_dir = "/s/genomes/human/hg19/ensembl_GRCh37.p13_release75/"

# %%
from gfeat import transcript

# %%
data = Genome(reference_name="hg19", annotation_name="hg19_all", 
              gtf_path_or_url=ref_dir + "Homo_sapiens.GRCh37.75.gtf", 
              transcript_fasta_path_or_url=ref_dir + "Homo_sapiens.GRCh37.75.dna.primary_assembly.fa")

# %%
data.index()

# %%
data.tr

# %%
data.transcript_ids()[:10]
# Out:
# ['ENST00000000233',
#  'ENST00000000412',
#  'ENST00000000442',
#  'ENST00000001008',
#  'ENST00000001146',
#  'ENST00000002125',
#  'ENST00000002165',
#  'ENST00000002501',
#  'ENST00000002596',
#  'ENST00000002829']

# %%
test_tran = data.transcript_by_id("ENST00000000233")

# %%
test_tran.

# %%
print(data.transcript_by_id("ENST00000623473.1"))
# Out:
# Transcript(transcript_id=ENST00000623473.1, name=CU104787.1-201, gene_id=ENSG00000280363.1, gene_name=CU104787.1, biotype=None, location=22:11065974-11067346)

# %%
print(data.transcript_by_id("ENST00000623473.1").sequence)
# Out:
# None

# %%
print(data.transcripts(22, '-'))
# Out:
# [Transcript(transcript_id=ENST00000615943.1, name=U2.14-201, gene_id=ENSG00000277248.1, gene_name=U2, biotype=None, location=22:10736171-10736283), Transcript(transcript_id=ENST00000618365.1, name=CU459211.1-201, gene_id=ENSG00000274237.1, gene_name=CU459211.1, biotype=None, location=22:10936023-10936161), Transcript(transcript_id=ENST00000635667.1, name=FRG1FP-001, gene_id=ENSG00000283047.1, gene_name=FRG1FP, biotype=None, location=22:10939388-10961338), Transcript(transcript_id=ENST00000623473.1, name=CU104787.1-201, gene_id=ENSG00000280363.1, gene_name=CU104787.1, biotype=None, location=22:11065974-11067346), Transcript(transcript_id=ENST00000612732.1, name=5_8S_rRNA.2-201, gene_id=ENSG00000276871.1, gene_name=5_8S_rRNA, biotype=None, location=22:11249809-11249959), Transcript(transcript_id=ENST00000614148.1, name=AC137488.1-201, gene_id=ENSG00000277683.1, gene_name=AC137488.1, biotype=None, location=22:11253605-11253719), Transcript(transcript_id=ENST00000614087.1, name=AC137488.
# ...

# %%
print(data.transcript_by_id("ENST00000623473.1"))
# Out:
# Transcript(transcript_id=ENST00000623473.1, name=CU104787.1-201, gene_id=ENSG00000280363.1, gene_name=CU104787.1, biotype=None, location=22:11065974-11067346)

# %%
tc = transcript.GFTranscript()

# %%
data = pyensembl.ensembl_release.EnsemblRelease(75)
mytranscript = GFTranscript("ENST00000369985", "MYO6-001", "6", 76458926, 76629253, "+", "protein_coding", "ENSG00000196586", data)
print mytranscript.codon_count()
mytranscript.utr3_motif_counts()
